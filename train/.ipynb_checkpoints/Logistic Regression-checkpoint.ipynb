# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd 
import numpy as np


from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.metrics import log_loss
from sklearn.linear_model import LogisticRegression

import pickle
import os
import os.path as path
import sys

# %%
save_dir = path.join(path.dirname(os.getcwd()), 'models')
data_dir = path.join(path.dirname(os.getcwd()), 'data', 'train_out.csv')

read = open('best_features.pkl', 'rb')
ranked_features = pickle.load(read)
read.close()

read = open('train_na.pkl', 'rb')
train_na = pickle.load(read)
read.close()

read = open('test_na.pkl', 'rb')
test_na = pickle.load(read)
read.close()

#ranked_features = ['expiration_date',
#                  'membership_expire_date',
#                  'registered_via_7.0',
#                  'is_auto_renew',
#                  'is_cancel']

train_out = pd.read_csv(data_dir)
train_out.index = train_out.msno
avg = np.mean(train_out.loc[train_na, 'is_churn'])
train_out = train_out[~train_na]
train_X = train_out.drop(['msno', 'is_churn'], axis = 1)
train_X = train_X[ranked_features]
train_y = train_out.is_churn

data_dir = path.join(path.dirname(os.getcwd()), 'data', 'test_out.csv')
test_out = pd.read_csv(data_dir)
test_out.index = test_out.msno
test_X = test_out.drop(['msno', 'is_churn'], axis = 1)
test_X = test_X[ranked_features]
test_y = test_out.is_churn

# %% [markdown]
# ### Training the Model

# %%
ranked_features
# Out:
# ['expiration_date',
#  '201702',
#  'is_auto_renew',
#  'membership_expire_date',
#  '201509',
#  'city_12.0',
#  'city_14.0',
#  'city_18.0',
#  '201502',
#  'city_10.0',
#  'registered_via_13.0',
#  'consecutive_ones',
#  'is_cancel',
#  'registered_via_7.0',
#  '201505',
#  'city_21.0',
#  'city_6.0',
#  'num_unq',
#  '201511']

# %%
log = LogisticRegression()
log.fit(train_X, train_y)
prob = log.predict_proba(train_X)

# %%
print('Logistic Regression log loss:           %f' % log_loss(train_y, prob))
save_dir = path.join(path.dirname(os.getcwd()), 'models', 'gbc_probs.pkl')
output = open(save_dir, 'wb')
pickle.dump(prob, output, protocol = pickle.HIGHEST_PROTOCOL)
output.close()
print('Logistic Regression probs saved!')
save_dir = path.join(path.dirname(os.getcwd()), 'models', 'log.pkl')
output = open(save_dir, 'wb')
pickle.dump(log, output, protocol = pickle.HIGHEST_PROTOCOL)
output.close()
print('Logistic Regression Classifier Saved!')
# Out:
# Logistic Regression log loss:           0.092731
# Logistic Regression probs saved!
# Logistic Regression Classifier Saved!

# %% [markdown]
# ### Creating Submission File

# %%
test_X = test_X.loc[~test_na]

pred = log.predict_proba(test_X)
pred = pred[:,1]
index = test_out.loc[~test_na, 'msno']
d = {
    'msno': index,
    'is_churn': pred
}

log_submission = pd.DataFrame(d)

log_submission = log_submission.append(pd.DataFrame({'msno': test_na[test_na == True].index, 
                                    'is_churn': [avg] * len(test_na[test_na == True].index)}))

save_dir = path.join(path.dirname(os.getcwd()), 'submissions')
log_submission.to_csv(path.join(save_dir, 'log_submission.csv'), index = False)
print('Saved Log Predictions to:      %s' % path.join(save_dir, 'gbc_submission.csv'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-90c96f635e34> in <module>()
#       9 }
#      10
# ---> 11 log_submission = pd.DataFrame(d)
#      12
#      13 log_submission = log_submission.append(pd.DataFrame({'msno': test_na[test_na == True].index,
#
# C:\Users\Michael\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     222                                  dtype=dtype, copy=copy)
#     223         elif isinstance(data, dict):
# --> 224             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     225         elif isinstance(data, ma.MaskedArray):
#     226             import numpy.ma.mrecords as mrecords
#
# C:\Users\Michael\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     358             arrays = [data[k] for k in keys]
#     359
# --> 360         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     361
#     362     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\Users\Michael\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5229     # figure out the index, if necessary
#    5230     if index is None:
# -> 5231         index = extract_index(arrays)
#    5232     else:
#    5233         index = _ensure_index(index)
#
# C:\Users\Michael\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    5287                     msg = ('array length %d does not match index length %d' %
#    5288                            (lengths[0], len(index)))
# -> 5289                     raise ValueError(msg)
#    5290             else:
#    5291                 index = _default_index(lengths[0])
#
# ValueError: array length 849780 does not match index length 970960

# %%
log_submission.loc[replace]
# Out:
#                                               is_churn  \
# msno
# c147tEGAJb25r45hf3QBGOMgDZY4Dj+4r5C55UzCo+Q=  0.013124
# 2Oo0AioVkvZnYs5U0WchMbdQtkIyPtkr59MUEPmDJ9g=  0.013124
# kSySd4rJkUzI7BUoH9YC0Xhw+jq90DGaAZduXE8Q0rQ=  0.005399
# 65+TjvOvEPR7r/5p8SxJc8kNkuTcpK9rtQJT4FeFEFo=  0.013124
# +8WKqzN6WM1FymTIq5seEiz4gNQcvboGEjZtJlzfhFc=       NaN
# S/A6p+3q+SW9bRzqbyHG5vLMSo5Db5DhsnhHv8qegV0=  0.005399
# +2FaW6slSzLNdwYOh0QOHZnMzodKMtPHCZF1d4C7Fb8=  0.013124
# pciLjGsP1RFA8vIEnTk97g7IJsrGiiZxpcIqPoKbkdY=  0.013124
# 4UoGsqadop9RCCDFQTBEI1PbD97h+1Omr+3uBAZ1Rjw=       NaN
# eAItuBGgGO511ed4RfCT1M6AqA0+7h+Og2fpd8XrkzQ=       NaN
# 2T8B7Ck/oY8ocYTpLOvSUrOLghGQ+rQj8wYo6eF/e1E=       NaN
# sNFUeSU/BIpjppHYJMnhPB3hAsLcCLI/Eb/46T6YU/g=       NaN
# LPf9RD9BHgTb0qWJ95p7ogY/NOmmU4dsODg27MFaMHs=       NaN
# hFW2vNJ7yAd+rDnhIlysUBkZaKbsZIQgOB7JpAkHS8Y=       NaN
# 86DITgpR8u6TRCgB5UhxJju95QB2iL9Vf1Jon/FvZbg=       NaN
# OOr0rrWnhy6+aFe6MxhBZqVertNKdPARytf8MPNsYHc=       NaN
# pWGit2OxulS0VW+RcTE6O7/TSDjKVKLFTvg5mip+bOc=  0.013124
# t9Sb6LTGNHGnyr+05D9YRfhGY8P1sKMBDH/zO1Aza78=  0.013124
# 7V5GgYqasKQjzLPuZ8LIY8g90Uu7/Qk6GtMkVv2kkXg=       NaN
# 8n4P2ruB023NPZMDAMIaxnMvBYO6v6IbLO7miJSEJL0=       NaN
# gFLappcFDt44Bb1XjfaQMua6jM4GhIx4IvulFBK+fuA=       NaN
# dccse7IRMVtaNvl28ozw+aMEc6YWl/EH1wESl+6E+9c=  0.013124
